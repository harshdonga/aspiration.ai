# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib

matplotlib.use('nbagg')
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import rcParams #Size of plots

# %%
df=pd.read_csv("week2.csv");
df.head()
# Out:
#   Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0   RCOM     EQ  2017-05-15       32.45       32.50       32.60      31.70
# 1   RCOM     EQ  2017-05-16       32.00       32.05       32.35      31.85
# 2   RCOM     EQ  2017-05-17       32.10       32.10       32.30      31.70
# 3   RCOM     EQ  2017-05-18       31.95       31.60       31.90      31.00
# 4   RCOM     EQ  2017-05-19       31.05       31.20       31.45      30.25
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       32.00        32.00          31.99                7126316
# 1       32.00        32.10          32.12                7274881
# 2       31.90        31.95          31.97                6245114
# 3       31.05        31.05          31.34               11189938
# 4       30.55        30.55          30.80               11898780
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# ...

# %%
df['Date'] = pd.to_datetime(df.Date) 
df['Date'].describe
# Out:
# <bound method NDFrame.describe of 0     2017-05-15
# 1     2017-05-16
# 2     2017-05-17
# 3     2017-05-18
# 4     2017-05-19
#          ...
# 489   2019-05-07
# 490   2019-05-08
# 491   2019-05-09
# 492   2019-05-10
# 493   2019-05-13
# Name: Date, Length: 494, dtype: datetime64[ns]>

# %%
plt.rcParams['figure.figsize'] = (14,8)

x1=df['Date'].tolist()
y1=df['Day_Perc_Change'].tolist()
y2=df['Total Traded Quantity'].tolist()


plt.figure(1)

plt.subplot(211)
plt.ylabel("Date")
plt.xlabel('Day Percentage Change')
plt.stem(x1,y1,'b')


plt.subplot(212)
plt.xlabel("Date")
plt.ylabel('Volume')
plt.plot(x1,y2,'r')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1008">
# c:\users\keyur\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# c:\users\keyur\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %%
# plt.figure(2)


grp_tr=df.groupby(by="Trends")
grp_tr.first()
# Out:
#                     Symbol Series       Date  Prev Close  Open Price  \
# Trends
# Slight or No change   RCOM     EQ 2017-05-15       32.45        32.5
# Slight positive       RCOM     EQ 2018-05-17       10.50        10.4
#
#                      High Price  Low Price  Last Price  Close Price  \
# Trends
# Slight or No change       32.60      31.70        32.0         32.0
# Slight positive           17.75      10.05        17.4         16.4
#
#                      Average Price  Total Traded Quantity      Turnover  \
# Trends
# Slight or No change          31.99                7126316  2.279973e+08
# Slight positive              14.13              556849068  7.867072e+09
#
#                      No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# Trends
# Slight or No change          11883          1908042                   26.77
# Slight positive             317217         51044560                    9.17
#
#                      Year  Month  Day_Perc_Change
# Trends
# ...

# %%
count_tr=grp_tr.agg('count')

# %%
# %matplotlib inline
plt.figure(2)
labels=['Slight or No change','Slight positive']
plt.pie(count_tr['Date'],labels=labels, autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x215a1d652e8>,
# ...
#  [Text(-1.0999777562659157, 0.0069954070790757385, 'Slight or No change'),
#   Text(1.0999777562352147, -0.006995411906607436, 'Slight positive')],
#  [Text(-0.5999878670541358, 0.003815676588586766, '99.8%'),
#   Text(0.5999878670373897, -0.0038156792217858737, '0.2%')])

# %%
plt.figure(4)
plt.subplot(211)
avg_tr=grp_tr.agg('mean')
avg_tr['Total Traded Quantity'].plot(kind='bar',title='Mean of volume in trends',color='b')


plt.subplot(212)
median_tr=grp_tr.agg('median')
median_tr['Total Traded Quantity'].plot(kind='bar',title='Median of volume in trends',color='r')

# %%
df['Day_Perc_Change'].plot.hist()

# %%
df_tcs=pd.read_csv('Large_Cap//TCS.csv');
df_hdfc=pd.read_csv('Large_Cap//HDFC.csv');
df_lt=pd.read_csv('Large_Cap//LT.csv');
df_infy=pd.read_csv('Large_Cap//INFY.csv');

# %%
df_tcs=df_tcs[df_tcs['Series']=='EQ']
print('No of points left: ',df_tcs.shape[0])
df_tcs.head()
# Out:
# No of points left:  494
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TCS     EQ  15-May-2017     2360.65      2375.1     2377.95    2341.60
# 1    TCS     EQ  16-May-2017     2365.10      2380.0     2435.00    2373.45
# 2    TCS     EQ  17-May-2017     2429.15      2433.5     2460.75    2423.00
# 3    TCS     EQ  18-May-2017     2455.35      2450.0     2572.00    2442.25
# 4    TCS     EQ  19-May-2017     2536.20      2536.2     2540.55    2486.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     2368.00      2365.10        2352.60                 908802
# 1     2425.10      2429.15        2410.26                1800513
# 2     2450.00      2455.35        2443.31                1438099
# 3     2525.00      2536.20        2525.78                2569297
# 4     2503.85      2507.15        2506.58                 893022
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df_hdfc=df_hdfc[df_hdfc['Series']=='EQ']
print('No of points left: ',df_hdfc.shape[0])
df_hdfc.head()
# Out:
# No of points left:  494
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  15-May-2017     1549.80      1554.5     1572.60    1554.10
# 2   HDFC     EQ  16-May-2017     1559.50      1558.0     1569.00    1554.00
# 3   HDFC     EQ  17-May-2017     1566.55      1565.5     1570.95    1549.75
# 5   HDFC     EQ  18-May-2017     1552.50      1547.0     1558.60    1526.50
# 7   HDFC     EQ  19-May-2017     1537.05      1545.0     1548.00    1515.35
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1561.0      1559.50        1562.62                1270297
# 2      1568.0      1566.55        1564.05                2114918
# 3      1550.1      1552.50        1557.08                2161434
# 5      1545.0      1537.05        1539.03                2404372
# 7      1526.5      1520.60        1526.14                2142433
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df_lt=df_lt[df_lt['Series']=='EQ']
print('No of points left: ',df_lt.shape[0])
df_lt.head()
# Out:
# No of points left:  494
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     LT     EQ  15-May-2017     1740.60     1748.60     1751.55    1736.50
# 1     LT     EQ  16-May-2017     1742.40     1747.00     1748.25    1727.55
# 2     LT     EQ  17-May-2017     1740.70     1743.90     1764.00    1730.50
# 3     LT     EQ  18-May-2017     1755.45     1739.65     1750.10    1716.40
# 4     LT     EQ  19-May-2017     1722.60     1729.00     1734.00    1697.55
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1742.00      1742.40        1743.15                 797134
# 1     1740.60      1740.70        1736.62                1102926
# 2     1754.30      1755.45        1749.36                1668586
# 3     1722.10      1722.60        1725.53                1437220
# 4     1720.05      1724.55        1718.73                1512094
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df_infy=df_infy[df_infy['Series']=='EQ']
print('No of points left: ',df_infy.shape[0])
df_infy.head()
# Out:
# No of points left:  494
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df_close=pd.concat([df['Close Price'],df_tcs['Close Price'],df_lt['Close Price'],df_hdfc['Close Price'],df_infy['Close Price']], axis=1)

# %%
df_close=df_close[:494]

# %%
df_close.columns=['RCOM','TCS','LT','HDFC','INFY']
df_close.head()
df_close.shape[0]
# Out:
# 494

# %%
# df_close['RCOM']=df_close['RCOM'].pct_change()
# df_close['TCS']=df_close['TCS'].pct_change()
# df_close['LT']=df_close['LT'].pct_change()
# df_close['HDFC']=df_close['HDFC'].pct_change()
# df_close['INFY']=df_close['INFY'].pct_change()

df_close_pct=df_close.pct_change()
df_close_pct.head()
# Out:
#        RCOM       TCS        LT      HDFC      INFY
# 0       NaN       NaN       NaN       NaN       NaN
# 1  0.003125  0.027081 -0.000976  0.000000  0.003626
# 2 -0.004673  0.010786  0.008474  0.004521 -0.002304
# 3 -0.028169  0.032928 -0.018713 -0.008969  0.009393
# 4 -0.016103 -0.011454  0.001132  0.000000 -0.003951

# %%
df_close_pct=df_close_pct.fillna(0)

# %%
df_corr=df_close_pct.corr(method='pearson')
df_corr.head()
# Out:
#           RCOM       TCS        LT      HDFC      INFY
# RCOM  1.000000 -0.058514  0.119905  0.018325  0.050815
# TCS  -0.058514  1.000000  0.010942 -0.017329  0.054644
# LT    0.119905  0.010942  1.000000  0.015947  0.025976
# HDFC  0.018325 -0.017329  0.015947  1.000000 -0.294194
# INFY  0.050815  0.054644  0.025976 -0.294194  1.000000

# %%
plt.figure(4)
sns.set_style("whitegrid");
sns.pairplot(df_corr, height=3);
plt.show()

# %%
df_rcom_roll=df_close_pct['RCOM'].rolling(7)

# %%
df_rcom_vol=df_rcom_roll.std()

# %%
plt.figure(5)
plt.plot(df_rcom_vol)
plt.show()

# %%
df_nifty=pd.read_csv('Nifty50//Nifty50.csv')
df_nifty=df_nifty['Close'].pct_change()
df_nifty_roll=df_nifty.rolling(7)
df_nifty_vol=df_nifty_roll.std()

# %%
plt.figure(6)
plt.plot(df_rcom_vol,label='RCOM',color='r')
plt.plot(df_nifty_vol,label='Nifty',color='b')
plt.legend()
plt.show()

# %%
def call_buy_sell(n1,n2,df,Day):
    df_roll=df.rolling(n1).mean()
    df_roll_2=df.rolling(n2).mean()
    plt.figure(6)
    plt.plot(df_roll,label=str(n1) + 'SMA',color='r')
    plt.plot(df_roll_2,label=str(n2) + 'SMA',color='b')
    plt.legend()
    plt.show()
    
    first=df_roll.iloc[Day]
    second=df_roll_2.iloc[Day]
    if(first>second):
        return 'BUY'
    else:
        return 'SELL'
    
    
call_buy_sell(21,34,df_close['RCOM'],15)
# Out:
# 'SELL'

# %%
df_roll_avg=df_close['RCOM'].rolling(14).mean()
df_std=df_close['RCOM'].std()
df_upper=df_roll_avg+(2*df_std)
df_lower=df_roll_avg-(2*df_std)

plt.figure(7)
plt.plot(df_roll_avg,label='Rolling mean',color='r')
plt.plot(df_upper,label='Bollinger upper band',color='b')
plt.plot(df_lower,label='Bollinger lower band',color='g')
plt.plot(df_close['RCOM'],label='Average Daily Stock',color='black')
plt.legend()
plt.show()

# %%
df['Rolling Mean 14 Days']=df_roll_avg
df['BOLU']=df_upper
df['BOLD']=df_lower

# %%
df.to_csv('week3.csv',index=False)
