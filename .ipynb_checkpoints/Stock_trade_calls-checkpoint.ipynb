# %%
import pandas as pd
import matplotlib.pyplot as plt
import time
import warnings
import numpy as np
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.linear_model import SGDClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from collections import Counter
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# c:\users\keyur\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df=pd.read_csv('week3_new.csv')

# %%
df.head()
# Out:
#   Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0   RCOM     EQ  2017-06-01       19.90        20.5       21.15      19.85
# 1   RCOM     EQ  2017-06-02       20.75        20.5       21.65      20.05
# 2   RCOM     EQ  2017-06-05       20.65        21.4       21.60      20.65
# 3   RCOM     EQ  2017-06-06       20.80        20.8       20.85      19.75
# 4   RCOM     EQ  2017-06-07       20.15        19.7       19.70      19.15
#
#    Last Price  Close Price  Average Price  ...  No. of Trades  \
# 0       20.70        20.75          20.56  ...         100392
# 1       20.70        20.65          20.67  ...          76785
# 2       20.75        20.80          20.99  ...          48525
# 3       20.20        20.15          20.18  ...          37179
# 4       19.30        19.35          19.45  ...          35975
#
#    Deliverable Qty  % Dly Qt to Traded Qty  Year  Month  Day_Perc_Change  \
# 0         23621882                   19.82  2017      6         0.042714
# 1         18572290                   20.17  2017      6        -0.004819
# 2         20457641                   32.72  2017      6         0.007264
# 3          8623150                   19.37  2017      6        -0.031250
# 4         11802183                   26.21  2017      6        -0.039702
#
#                 Trends  Rolling Mean 14 Days       BOLU       BOLD
# 0  Slight or No change             26.728571  41.363329  12.093814
# 1  Slight or No change             25.917857  40.552615  11.283099
# 2  Slight or No change             25.110714  39.745472  10.475956
# 3  Slight or No change             24.267857  38.902615   9.633099
# 4  Slight or No change             23.432143  38.066901   8.797385
#
# [5 rows x 22 columns]

# %%
len=df.shape[0]
df['Call']=pd.DataFrame([np.nan] * (len))

for i in range(len):

    if(df['Close Price'].iloc[i]<df['BOLD'].iloc[i]):
        df['Call'].iloc[i]='Buy'
        
    elif(df['Close Price'].iloc[i]>df['BOLD'].iloc[i] and df['Close Price'].iloc[i]<df['Rolling Mean 14 Days'].iloc[i]):
        df['Call'].iloc[i]='Hold Buy/ Liquidate Short'
    
    elif(df['Close Price'].iloc[i]>df['Rolling Mean 14 Days'].iloc[i] and df['Close Price'].iloc[i]<df['BOLU'].iloc[i]):
        df['Call'].iloc[i]='Hold Short/ Liquidate Buy'
        
    elif(df['Close Price'].iloc[i]>df['BOLU'].iloc[i]):
        df['Call'].iloc[i]='Short'

# %%
df.groupby(by='Call').agg('count')
# Out:
#                            Symbol  Series  Date  Prev Close  Open Price  \
# Call
# Hold Buy/ Liquidate Short     317     317   317         317         317
# Hold Short/ Liquidate Buy     161     161   161         161         161
# Short                           3       3     3           3           3
#
#                            High Price  Low Price  Last Price  Close Price  \
# Call
# Hold Buy/ Liquidate Short         317        317         317          317
# Hold Short/ Liquidate Buy         161        161         161          161
# Short                               3          3           3            3
#
#                            Average Price  ...  No. of Trades  Deliverable Qty  \
# Call                                      ...
# Hold Buy/ Liquidate Short            317  ...            317              317
# Hold Short/ Liquidate Buy            161  ...            161              161
# Short                                  3  ...              3                3
#
#                            % Dly Qt to Traded Qty  Year  Month  \
# Call
# Hold Buy/ Liquidate Short                     317   317    317
# Hold Short/ Liquidate Buy                     161   161    161
# Short                                           3     3      3
#
#                            Day_Perc_Change  Trends  Rolling Mean 14 Days  \
# Call
# Hold Buy/ Liquidate Short              317     317                   317
# Hold Short/ Liquidate Buy              161     161                   161
# Short                                    3       3                     3
#
#                            BOLU  BOLD
# Call
# Hold Buy/ Liquidate Short   317   317
# Hold Short/ Liquidate Buy   161   161
# Short                         3     3
#
# [3 rows x 22 columns]

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder=LabelEncoder()

df['Call_num']=labelencoder.fit_transform(df['Call'])
df
# Out:
#     Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0     RCOM     EQ  2017-06-01       19.90       20.50       21.15      19.85
# 1     RCOM     EQ  2017-06-02       20.75       20.50       21.65      20.05
# 2     RCOM     EQ  2017-06-05       20.65       21.40       21.60      20.65
# 3     RCOM     EQ  2017-06-06       20.80       20.80       20.85      19.75
# 4     RCOM     EQ  2017-06-07       20.15       19.70       19.70      19.15
# ..     ...    ...         ...         ...         ...         ...        ...
# 476   RCOM     EQ  2019-05-07        2.00        2.00        2.10       2.00
# 477   RCOM     EQ  2019-05-08        2.10        2.10        2.20       2.10
# 478   RCOM     EQ  2019-05-09        2.20        2.30        2.30       2.30
# 479   RCOM     EQ  2019-05-10        2.30        2.40        2.40       2.40
# 480   RCOM     EQ  2019-05-13        2.40        2.45        2.50       2.30
#
#      Last Price  Close Price  Average Price  ...  % Dly Qt to Traded Qty  \
# 0         20.70        20.75          20.56  ...                   19.82
# 1         20.70        20.65          20.67  ...                   20.17
# 2         20.75        20.80          20.99  ...                   32.72
# 3         20.20        20.15          20.18  ...                   19.37
# 4         19.30        19.35          19.45  ...                   26.21
# ..          ...          ...            ...  ...                     ...
# 476        2.10         2.10           2.06  ...                   54.02
# 477        2.20         2.20           2.18  ...                   54.48
# 478        2.30         2.30           2.30  ...                   98.19
# 479        2.40         2.40           2.40  ...                  100.00
# 480        2.30         2.30           2.40  ...                   62.15
#
#      Year  Month  Day_Perc_Change               Trends  Rolling Mean 14 Days  \
# 0    2017      6         0.042714  Slight or No change             26.728571
# 1    2017      6        -0.004819  Slight or No change             25.917857
# 2    2017      6         0.007264  Slight or No change             25.110714
# 3    2017      6        -0.031250  Slight or No change             24.267857
# 4    2017      6        -0.039702  Slight or No change             23.432143
# ..    ...    ...              ...                  ...                   ...
# 476  2019      5         0.050000  Slight or No change              2.178571
# 477  2019      5         0.047619  Slight or No change              2.142857
# 478  2019      5         0.045455  Slight or No change              2.121429
# 479  2019      5         0.043478  Slight or No change              2.114286
# 480  2019      5        -0.041667  Slight or No change              2.107143
#
#           BOLU       BOLD                       Call  Call_num
# 0    41.363329  12.093814  Hold Buy/ Liquidate Short         0
# 1    40.552615  11.283099  Hold Buy/ Liquidate Short         0
# 2    39.745472  10.475956  Hold Buy/ Liquidate Short         0
# 3    38.902615   9.633099  Hold Buy/ Liquidate Short         0
# 4    38.066901   8.797385  Hold Buy/ Liquidate Short         0
# ..         ...        ...                        ...       ...
# 476  16.813329 -12.456186  Hold Buy/ Liquidate Short         0
# 477  16.777615 -12.491901  Hold Short/ Liquidate Buy         1
# 478  16.756186 -12.513329  Hold Short/ Liquidate Buy         1
# 479  16.749044 -12.520472  Hold Short/ Liquidate Buy         1
# 480  16.741901 -12.527615  Hold Short/ Liquidate Buy         1
#
# [481 rows x 24 columns]

# %%
df_train=df[['Rolling Mean 14 Days','BOLU','BOLD','Call_num']]

# %%
X_train,X_test, y_train, y_test = train_test_split(df_train[['Rolling Mean 14 Days','BOLU','BOLD']], df_train['Call_num'], stratify=df_train['Call_num'], test_size=0.2)

# %%
# This function plots the confusion matrices given y_i, y_i_hat.

from sklearn import metrics

def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    
    A =(((C.T)/(C.sum(axis=1))).T)
    
    B =(C/C.sum(axis=0))
    
    labels = [0,1,2]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    print('ACCURACY IS:',metrics.accuracy_score(test_y, predict_y))

# %%
print("Number of data points in train data :",X_train.shape)
print("Number of data points in test data :",test_df.shape)
# Out:
# Number of data points in train data : (384, 3)
# Number of data points in test data : (97, 3)

# %% [markdown]
# <h2>WORST MODEL (RANDOMLY ASSIGNING CLASSES)</h2>

# %%
from sklearn import metrics

test_len=X_test.shape[0]
predicted_y = np.zeros((test_len,3))
for i in range(test_len):
    rand_probs = np.random.rand(1,3)
    predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test, predicted_y, eps=1e-15))

predicted_y =np.argmax(predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Log loss on Test Data using Random Model 1.3194255572016227
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# ACCURACY IS: 0.29896907216494845

# %% [markdown]
# <h2>LOGISTIC REGRESSION WITH HYPERPARAMETER TUNING</h2>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :",test_len)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6907585149141603
# For values of alpha =  0.0001 The log loss is: 0.6886669037319304
# For values of alpha =  0.001 The log loss is: 0.6892077316150673
# For values of alpha =  0.01 The log loss is: 0.6890853275649558
# For values of alpha =  0.1 The log loss is: 0.6890853179100715
# For values of alpha =  1 The log loss is: 0.689085328339611
# For values of alpha =  10 The log loss is: 0.6890853323479607
# For values of best alpha =  0.0001 The train log loss is: 0.673808984186552
# For values of best alpha =  0.0001 The test log loss is: 0.6886669037319304
# Total number of data points : 97
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# ACCURACY IS: 0.6597938144329897

# %% [markdown]
# <h2>LINEAR SVM WITH HYPERPARAMETER TUNING</h2>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

log_error_array=[]
for i in alpha:
    clf = SGDClassifier(class_weight='balanced',alpha=i, penalty='l1', loss='hinge', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(class_weight='balanced',alpha=alpha[best_alpha], penalty='l1', loss='hinge', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", test_len)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6886387100293744
# For values of alpha =  0.0001 The log loss is: 0.690675200449095
# For values of alpha =  0.001 The log loss is: 0.6875392227534709
# For values of alpha =  0.01 The log loss is: 0.6882148604334177
# For values of alpha =  0.1 The log loss is: 0.6906711240838618
# For values of alpha =  1 The log loss is: 0.6886862355283155
# For values of alpha =  10 The log loss is: 0.687848603411755
# For values of best alpha =  0.001 The train log loss is: 0.6749792625276426
# For values of best alpha =  0.001 The test log loss is: 0.6875392227534709
# Total number of data points : 97
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# ACCURACY IS: 0.6597938144329897

# %% [markdown]
# <h2>KNN Neighbours with hyperparameter tuning</h2>

# %%
alpha = [2,3,5, 11, 15, 21, 31, 41, 51, 99]

log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

    
fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

best_alpha = np.argmin(log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", test_len)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# for alpha = 2
# For values of alpha =  2 The log loss is: 0.6880852626038637
# for alpha = 3
# For values of alpha =  3 The log loss is: 0.6953075939741522
# for alpha = 5
# For values of alpha =  5 The log loss is: 0.6897100125915595
# for alpha = 11
# For values of alpha =  11 The log loss is: 0.6962223971415802
# for alpha = 15
# For values of alpha =  15 The log loss is: 0.6883684116417634
# for alpha = 21
# For values of alpha =  21 The log loss is: 0.6821734743861895
# for alpha = 31
# For values of alpha =  31 The log loss is: 0.6883598996839243
# for alpha = 41
# For values of alpha =  41 The log loss is: 0.6894609033996217
# for alpha = 51
# For values of alpha =  51 The log loss is: 0.6879548018563331
# for alpha = 99
# For values of alpha =  99 The log loss is: 0.6831635866269039
# For values of best alpha =  21 The train log loss is: 0.6605918528178708
# For values of best alpha =  21 The test log loss is: 0.6821734743861895
# Total number of data points : 97
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# ACCURACY IS: 0.6597938144329897

# %%
df_tcs=pd.read_csv('Large_Cap/TCS.csv')
df_tcs
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      TCS     EQ  15-May-2017     2360.65     2375.10     2377.95    2341.60
# 1      TCS     EQ  16-May-2017     2365.10     2380.00     2435.00    2373.45
# 2      TCS     EQ  17-May-2017     2429.15     2433.50     2460.75    2423.00
# 3      TCS     EQ  18-May-2017     2455.35     2450.00     2572.00    2442.25
# 4      TCS     EQ  19-May-2017     2536.20     2536.20     2540.55    2486.00
# ..     ...    ...          ...         ...         ...         ...        ...
# 493    TCS     EQ  07-May-2019     2157.85     2160.05     2184.35    2138.80
# 494    TCS     EQ  08-May-2019     2151.95     2151.00     2168.00    2130.40
# 495    TCS     EQ  09-May-2019     2152.85     2145.00     2184.10    2136.10
# 496    TCS     EQ  10-May-2019     2172.55     2175.00     2192.00    2125.85
# 497    TCS     EQ  13-May-2019     2135.80     2133.00     2167.00    2121.65
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       2368.00      2365.10        2352.60                 908802
# 1       2425.10      2429.15        2410.26                1800513
# 2       2450.00      2455.35        2443.31                1438099
# 3       2525.00      2536.20        2525.78                2569297
# 4       2503.85      2507.15        2506.58                 893022
# ..          ...          ...            ...                    ...
# 493     2154.00      2151.95        2163.53                2201698
# 494     2156.00      2152.85        2151.85                1824895
# 495     2171.20      2172.55        2166.98                2264162
# 496     2130.25      2135.80        2161.83                2039633
# 497     2134.00      2128.75        2143.87                1701744
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    2.138043e+09          30047           712450                   78.39
# 1    4.339703e+09          58476          1167534                   64.84
# 2    3.513729e+09          86412          1031752                   71.74
# 3    6.489478e+09         111566          1135613                   44.20
# 4    2.238430e+09          63112           517461                   57.94
# ..            ...            ...              ...                     ...
# 493  4.763441e+09          86096           975603                   44.31
# 494  3.926902e+09          77713           781526                   42.83
# 495  4.906405e+09         106297          1251459                   55.27
# 496  4.409349e+09          85446           873181                   42.81
# 497  3.648325e+09          74014           677242                   39.80
#
# [498 rows x 15 columns]

# %%
df_roll_avg=df_tcs['Close Price'].rolling(14).mean()
df_std=df_tcs['Close Price'].std()
df_upper=df_roll_avg+(2*df_std)
df_lower=df_roll_avg-(2*df_std)

df_tcs['Rolling Mean 14 Days']=df_roll_avg
df_tcs['BOLU']=df_upper
df_tcs['BOLD']=df_lower
df_tcs=df_tcs.dropna()
df_tcs.head()
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 13    TCS     EQ  01-Jun-2017     2546.60     2530.00     2564.00    2530.00
# 14    TCS     EQ  02-Jun-2017     2553.60     2556.25     2591.85    2552.50
# 15    TCS     EQ  05-Jun-2017     2564.90     2565.00     2619.90    2560.15
# 16    TCS     EQ  06-Jun-2017     2603.95     2631.00     2708.95    2630.00
# 17    TCS     EQ  07-Jun-2017     2696.00     2697.00     2700.00    2576.55
#
#     Last Price  Close Price  Average Price  Total Traded Quantity  \
# 13     2553.00      2553.60        2552.85                 540032
# 14     2560.00      2564.90        2568.84                 677824
# 15     2616.00      2603.95        2577.20                 750094
# 16     2705.00      2696.00        2693.18                2973360
# 17     2613.95      2615.25        2624.95                2463888
#
#         Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 13  1.378618e+09          38315           370004                   68.52
# 14  1.741220e+09          43736           511928                   75.53
# 15  1.933140e+09          39041           490594                   65.40
# 16  8.007781e+09         132494          1888281                   63.51
# 17  6.467589e+09         109104          1265805                   51.37
#
#     Rolling Mean 14 Days         BOLU         BOLD
# 13           2523.725000  3449.933429  1597.516571
# 14           2537.996429  3464.204857  1611.788000
# 15           2550.482143  3476.690571  1624.273714
# 16           2567.671429  3493.879857  1641.463000
# 17           2573.317857  3499.526286  1647.109429

# %%
len=df_tcs.shape[0]
df_tcs['Call']=pd.DataFrame([np.nan] * (len))

for i in range(len):

    if(df_tcs['Close Price'].iloc[i]<df_tcs['BOLD'].iloc[i]):
        df_tcs['Call'].iloc[i]='Buy'
        
    elif(df_tcs['Close Price'].iloc[i]>df_tcs['BOLD'].iloc[i] and df_tcs['Close Price'].iloc[i]<df_tcs['Rolling Mean 14 Days'].iloc[i]):
        df_tcs['Call'].iloc[i]='Hold Buy/ Liquidate Short'
    
    elif(df_tcs['Close Price'].iloc[i]>df_tcs['Rolling Mean 14 Days'].iloc[i] and df_tcs['Close Price'].iloc[i]<df_tcs['BOLU'].iloc[i]):
        df_tcs['Call'].iloc[i]='Hold Short/ Liquidate Buy'
        
    elif(df_tcs['Close Price'].iloc[i]>df_tcs['BOLU'].iloc[i]):
        df_tcs['Call'].iloc[i]='Short'

# %%
df_tcs.groupby(by='Call').agg('count')
# Out:
#                            Symbol  Series  Date  Prev Close  Open Price  \
# Call
# Buy                             6       6     6           6           6
# Hold Buy/ Liquidate Short     192     192   192         192         192
# Hold Short/ Liquidate Buy     287     287   287         287         287
#
#                            High Price  Low Price  Last Price  Close Price  \
# Call
# Buy                                 6          6           6            6
# Hold Buy/ Liquidate Short         192        192         192          192
# Hold Short/ Liquidate Buy         287        287         287          287
#
#                            Average Price  Total Traded Quantity  Turnover  \
# Call
# Buy                                    6                      6         6
# Hold Buy/ Liquidate Short            192                    192       192
# Hold Short/ Liquidate Buy            287                    287       287
#
#                            No. of Trades  Deliverable Qty  \
# Call
# Buy                                    6                6
# Hold Buy/ Liquidate Short            192              192
# Hold Short/ Liquidate Buy            287              287
#
#                            % Dly Qt to Traded Qty  Rolling Mean 14 Days  BOLU  \
# Call
# Buy                                             6                     6     6
# Hold Buy/ Liquidate Short                     192                   192   192
# Hold Short/ Liquidate Buy                     287                   287   287
#
#                            BOLD
# Call
# Buy                           6
# Hold Buy/ Liquidate Short   192
# Hold Short/ Liquidate Buy   287

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder=LabelEncoder()

df_tcs['Call']=labelencoder.fit_transform(df_tcs['Call'])
df_tcs
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 13     TCS     EQ  01-Jun-2017     2546.60     2530.00     2564.00    2530.00
# 14     TCS     EQ  02-Jun-2017     2553.60     2556.25     2591.85    2552.50
# 15     TCS     EQ  05-Jun-2017     2564.90     2565.00     2619.90    2560.15
# 16     TCS     EQ  06-Jun-2017     2603.95     2631.00     2708.95    2630.00
# 17     TCS     EQ  07-Jun-2017     2696.00     2697.00     2700.00    2576.55
# ..     ...    ...          ...         ...         ...         ...        ...
# 493    TCS     EQ  07-May-2019     2157.85     2160.05     2184.35    2138.80
# 494    TCS     EQ  08-May-2019     2151.95     2151.00     2168.00    2130.40
# 495    TCS     EQ  09-May-2019     2152.85     2145.00     2184.10    2136.10
# 496    TCS     EQ  10-May-2019     2172.55     2175.00     2192.00    2125.85
# 497    TCS     EQ  13-May-2019     2135.80     2133.00     2167.00    2121.65
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 13      2553.00      2553.60        2552.85                 540032
# 14      2560.00      2564.90        2568.84                 677824
# 15      2616.00      2603.95        2577.20                 750094
# 16      2705.00      2696.00        2693.18                2973360
# 17      2613.95      2615.25        2624.95                2463888
# ..          ...          ...            ...                    ...
# 493     2154.00      2151.95        2163.53                2201698
# 494     2156.00      2152.85        2151.85                1824895
# 495     2171.20      2172.55        2166.98                2264162
# 496     2130.25      2135.80        2161.83                2039633
# 497     2134.00      2128.75        2143.87                1701744
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 13   1.378618e+09          38315           370004                   68.52
# 14   1.741220e+09          43736           511928                   75.53
# 15   1.933140e+09          39041           490594                   65.40
# 16   8.007781e+09         132494          1888281                   63.51
# 17   6.467589e+09         109104          1265805                   51.37
# ..            ...            ...              ...                     ...
# 493  4.763441e+09          86096           975603                   44.31
# 494  3.926902e+09          77713           781526                   42.83
# 495  4.906405e+09         106297          1251459                   55.27
# 496  4.409349e+09          85446           873181                   42.81
# 497  3.648325e+09          74014           677242                   39.80
#
#      Rolling Mean 14 Days         BOLU         BOLD  Call
# 13            2523.725000  3449.933429  1597.516571     2
# 14            2537.996429  3464.204857  1611.788000     2
# 15            2550.482143  3476.690571  1624.273714     2
# 16            2567.671429  3493.879857  1641.463000     2
# 17            2573.317857  3499.526286  1647.109429     2
# ..                    ...          ...          ...   ...
# 493           2161.478571  3087.687000  1235.270143     1
# 494           2171.360714  3097.569143  1245.152286     1
# 495           2175.592857  3101.801286  1249.384429     1
# 496           2175.878571  3102.087000  1249.670143     1
# 497           2174.357143  3100.565571  1248.148714     1
#
# [485 rows x 19 columns]

# %%
X_train_tcs,X_test_tcs, y_train_tcs, y_test_tcs = train_test_split(df_tcs[['Rolling Mean 14 Days','BOLU','BOLD']], df_tcs['Call'], stratify=df_tcs['Call'], test_size=0.2)

# %% [markdown]
# <h2>LOGISTIC REGRESSION ON TCS</h2>

# %%
test_len_tcs=X_test_tcs.shape[0]

predict_y_tcs = sig_clf.predict_proba(X_train_tcs)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train_tcs, predict_y_tcs, labels=clf.classes_, eps=1e-15))
predict_y_tcs = sig_clf.predict_proba(X_test_tcs)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test_tcs, predict_y_tcs, labels=clf.classes_, eps=1e-15))
predicted_y_tcs =np.argmax(predict_y_tcs,axis=1)
print("Total number of data points :",test_len_tcs)
plot_confusion_matrix(y_test_tcs, predicted_y_tcs)
# Out:
# For values of best alpha =  21 The train log loss is: 2.929263581536729
# For values of best alpha =  21 The test log loss is: 2.953639696211593
# Total number of data points : 97
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# ACCURACY IS: 0.010309278350515464

# %% [markdown]
# <h2>ALL THE MODELS HAVE THE SAME ACCURACY, AS THE AMOUNT OF DATA IS INSUFFICIENT</h2>
# <h2>EVEN AFTER CLASS BALANCING THE CLASS PREDICTED IS ALWAYS THE FIRST ONE AND THUS THIS MODEL SHOULD NOT BE USED </h2>

# %%
df_rcom=pd.read_csv('RCOM.csv')
df_rcom.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   RCOM     EQ  15-May-2017       32.45       32.50       32.60      31.70
# 1   RCOM     EQ  16-May-2017       32.00       32.05       32.35      31.85
# 2   RCOM     EQ  17-May-2017       32.10       32.10       32.30      31.70
# 3   RCOM     EQ  18-May-2017       31.95       31.60       31.90      31.00
# 4   RCOM     EQ  19-May-2017       31.05       31.20       31.45      30.25
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       32.00        32.00          31.99                7126316
# 1       32.00        32.10          32.12                7274881
# 2       31.90        31.95          31.97                6245114
# 3       31.05        31.05          31.34               11189938
# 4       30.55        30.55          30.80               11898780
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  2.279973e+08          11883          1908042                   26.77
# 1  2.336877e+08           9976          2211910                   30.40
# 2  1.996360e+08           8838          1399815                   22.41
# 3  3.506776e+08          17051          3629175                   32.43
# 4  3.664547e+08          18065          3309529                   27.81

# %%
df_rcom=df_rcom[['Open Price','Close Price','Low Price','High Price']]

# %%
df_rcom=df_rcom.pct_change()

# %%
df_rcom=df_rcom.fillna(0)

# %%
df_rcom['Action']=
# Out:
#      Open Price  Close Price  Low Price  High Price
# 0      0.000000     0.000000   0.000000    0.000000
# 1     -0.013846     0.003125   0.004732   -0.007669
# 2      0.001560    -0.004673  -0.004710   -0.001546
# 3     -0.015576    -0.028169  -0.022082   -0.012384
# 4     -0.012658    -0.016103  -0.024194   -0.014107
# ..          ...          ...        ...         ...
# 489    0.000000     0.050000   0.000000    0.050000
# 490    0.050000     0.047619   0.050000    0.047619
# 491    0.095238     0.045455   0.095238    0.045455
# 492    0.043478     0.043478   0.043478    0.043478
# 493    0.020833    -0.041667  -0.041667    0.041667
#
# [494 rows x 4 columns]

# %%
len=df_rcom.shape[0]
#just pre-creating dataframe columns for below calculations
df_rcom['Action']=pd.DataFrame([np.nan] * (len))

# %%
for i in range(len-1):
    if(df_rcom['Close Price'].iloc[i+1]>df_rcom['Close Price'].iloc[i]):
        df_rcom['Action'].iloc[i]=1
    elif(df_rcom['Close Price'].iloc[i+1]<df_rcom['Close Price'].iloc[i]):
        df_rcom['Action'].iloc[i]=-1
    
df_rcom=df_rcom.dropna()

# %%
df_rcom
# Out:
#      Open Price  Close Price  Low Price  High Price  Action
# 0      0.000000     0.000000   0.000000    0.000000     1.0
# 1     -0.013846     0.003125   0.004732   -0.007669    -1.0
# 2      0.001560    -0.004673  -0.004710   -0.001546    -1.0
# 3     -0.015576    -0.028169  -0.022082   -0.012384     1.0
# 4     -0.012658    -0.016103  -0.024194   -0.014107    -1.0
# ..          ...          ...        ...         ...     ...
# 488    0.025641     0.025641   0.025641    0.025641     1.0
# 489    0.000000     0.050000   0.000000    0.050000    -1.0
# 490    0.050000     0.047619   0.050000    0.047619    -1.0
# 491    0.095238     0.045455   0.095238    0.045455    -1.0
# 492    0.043478     0.043478   0.043478    0.043478    -1.0
#
# [490 rows x 5 columns]

# %%
X_train_rcom,X_test_rcom, y_train_rcom, y_test_rcom = train_test_split(df_rcom[['Open Price','Close Price','Low Price','High Price']], df_rcom['Action'], stratify=df_rcom['Action'], test_size=0.2)

# %%
print('No of train points',X_train_rcom.shape)
print('No of test points',X_test_rcom.shape)
# Out:
# No of train points (392, 4)
# No of test points (98, 4)

# %% [markdown]
# <h2>RANDOM FOREST WITH HYPERPARAMETER TUNING</h2>

# %%
alpha = [50,100,150,200,250]
max_depth = [3,5,10]
log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(X_train_rcom,y_train_rcom)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(X_train_rcom, y_train_rcom)
        sig_clf_probs = sig_clf.predict_proba(X_test_rcom)
        log_error_array.append(log_loss(y_test_rcom, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(y_test_rcom, sig_clf_probs)) 


best_alpha = np.argmin(log_error_array)
print(best_alpha)
# Out:
# for n_estimators = 50 and max depth =  3
# Log Loss : 0.5702214965925494
# for n_estimators = 50 and max depth =  5
# Log Loss : 0.5553950378782335
# for n_estimators = 50 and max depth =  10
# Log Loss : 0.5531016787581918
# for n_estimators = 100 and max depth =  3
# Log Loss : 0.5732238675123222
# for n_estimators = 100 and max depth =  5
# Log Loss : 0.553780921486487
# for n_estimators = 100 and max depth =  10
# Log Loss : 0.5491528767866205
# for n_estimators = 150 and max depth =  3
# Log Loss : 0.5730576524441391
# for n_estimators = 150 and max depth =  5
# Log Loss : 0.5525114687608419
# for n_estimators = 150 and max depth =  10
# Log Loss : 0.5489391711072336
# for n_estimators = 200 and max depth =  3
# Log Loss : 0.5732705968670346
# for n_estimators = 200 and max depth =  5
# Log Loss : 0.5524398023102952
# for n_estimators = 200 and max depth =  10
# Log Loss : 0.5475373961854978
# for n_estimators = 250 and max depth =  3
# Log Loss : 0.5731962405383645
# for n_estimators = 250 and max depth =  5
# Log Loss : 0.5519203997757859
# for n_estimators = 250 and max depth =  10
# Log Loss : 0.5470000873996315
# 14

# %%
clf = RandomForestClassifier(n_estimators=250, criterion='gini', max_depth=10, random_state=42, n_jobs=-1)
clf.fit(X_train_rcom,y_train_rcom)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train_rcom, y_train_rcom)


predict_y = sig_clf.predict(X_test_rcom)
predict_y_proba=sig_clf.predict_proba(X_test_rcom)
print('For values of best estimator = ', 250, "The test log loss is:",log_loss(y_test_rcom, predict_y_proba, labels=clf.classes_, eps=1e-15))
# Out:
# For values of best estimator =  250 The test log loss is: 0.5470000873996314

# %%
print('ACCURACY:{} %'.format(metrics.accuracy_score(y_test_rcom, predict_y)*100))
# Out:
# ACCURACY:76.53061224489795 %

# %%
len=df_rcom.shape[0]
#just pre-creating dataframe columns for below calculations
df_rcom['df_returns']=pd.DataFrame([np.nan] * (len-1))


for i in range(len-1):
    df_rcom['df_returns'].iloc[i]=(df_rcom['Close Price'].iloc[i+1]-df_rcom['Close Price'].iloc[i])/(df_rcom['Close Price'].iloc[i])

# %%
df_rcom=df_rcom.replace([np.inf, -np.inf], np.nan)

# %%
df_rcom=df_rcom.dropna()
df_rcom['df_returns']=df_rcom['df_returns']*100

# %%
df_rcom
# Out:
#      Open Price  Close Price  Low Price  High Price  Action  df_returns
# 1     -0.013846     0.003125   0.004732   -0.007669    -1.0 -249.532710
# 2      0.001560    -0.004673  -0.004710   -0.001546    -1.0  502.816901
# 3     -0.015576    -0.028169  -0.022082   -0.012384     1.0  -42.834138
# 4     -0.012658    -0.016103  -0.024194   -0.014107    -1.0   52.454992
# 5     -0.014423    -0.024550  -0.018182   -0.020668    -1.0  146.040268
# ..          ...          ...        ...         ...     ...         ...
# 487    0.026316     0.026316   0.026316    0.026316    -1.0   -2.564103
# 488    0.025641     0.025641   0.025641    0.025641     1.0   95.000000
# 489    0.000000     0.050000   0.000000    0.050000    -1.0   -4.761905
# 490    0.050000     0.047619   0.050000    0.047619    -1.0   -4.545455
# 491    0.095238     0.045455   0.095238    0.045455    -1.0   -4.347826
#
# [479 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
list_rcom=df_rcom['df_returns'].tolist()
# plot the cumulative histogram
n, bins, patches = ax.hist(list_rcom, 50, density=True, histtype='step',
                           cumulative=True, label='Empirical')

plt.show()
